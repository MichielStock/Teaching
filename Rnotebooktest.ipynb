# %% [markdown]
# #Lineaire regressie

# %% [markdown]
# $y =ax+b^2$
#
# > lm(y~x)

# %%
x <- 1:5
y <- c(4, 5, 9, 15, 21)

# %%
plot(x, y)
# Out:
# plot without title

# %%
model <- lm(y~x)
summary(model)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#    1    2    3    4    5
#  1.2 -0.6 -1.4 -0.2  1.0
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -4.000      1.327  -3.015  0.05698 .
# x              4.800      0.400  12.000  0.00125 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.265 on 3 degrees of freedom
# Multiple R-squared:  0.9796,	Adjusted R-squared:  0.9728
# F-statistic:   144 on 1 and 3 DF,  p-value: 0.001245
